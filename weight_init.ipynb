# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import make_classification, make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from tensorflow.keras import initializers

# %%
X, y = make_classification(n_samples= 1000, n_features= 20, n_classes= 2, random_state= 42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=41)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def build_xavier_model():
    model = Sequential([
        Dense(64, input_dim= 20, activation= 'relu', kernel_initializer= 'glorot_uniform'),
        Dense(32, activation= 'relu', kernel_initializer= 'glorot_uniform'),
        Dense(1, activation= 'sigmoid', kernel_initializer= 'glorot_uniform')
    ])
    
    model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])
    return model

xavier_model = build_xavier_model()
history = xavier_model.fit(X_train, y_train, epochs= 10, batch_size= 22, validation_data= (X_test, y_test))
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6164 - loss: 0.6450 - val_accuracy: 0.7567 - val_loss: 0.5283
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7890 - loss: 0.4715 - val_accuracy: 0.8367 - val_loss: 0.4363
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8326 - loss: 0.3907 - val_accuracy: 0.8567 - val_loss: 0.3882
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8674 - loss: 0.3155 - val_accuracy: 0.8633 - val_loss: 0.3772
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.2969 - val_accuracy: 0.8667 - val_loss: 0.3630
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8882 - loss: 0.2853 - val_accuracy: 0.8567 - val_loss: 0.3515
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8981 - loss: 0.2657 - val_accuracy: 0.8600 - val_loss: 0.3574
# Epoch 8/10
# ...

# %%
### Model is slightly prone to overfitting so here i will use the concept of early stopping

# %%
# Function to plot accuracy and loss
def plot_history(history, title):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    # Plot accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Plot for model without dropout
plot_history(history, 'Modelwithglorat')

# %%
### At particular epoch overfitting starts (around 5-6

# %% [markdown]
# ### ZERO INITIALIZATION

# %%
X1, y1 = make_classification(n_samples= 100, n_features= 2, n_informative= 2, n_redundant=0, n_repeated=0,n_classes= 2,random_state= 41)

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size= 0.3, random_state=31)

# %%
plt.figure(figsize= (10, 6))
plt.scatter(X1[:, 0], X1[:, 1], c= y1)
plt.show()

# %%
model = Sequential([
    Dense(2, activation= 'relu', kernel_initializer= 'he_normal'),
    Dense(3, activation= 'relu', kernel_initializer= 'he_normal'),
    Dense(1, activation='sigmoid', kernel_initializer='he_normal')
])

model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])
history1 = model.fit(X1_train, y1_train, epochs= 15, batch_size= 30, validation_data= (X1_test, y1_test))
# Out:
# Epoch 1/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6179 - loss: 0.6144 - val_accuracy: 0.8333 - val_loss: 0.5595
# Epoch 2/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8280 - loss: 0.6010 - val_accuracy: 0.8333 - val_loss: 0.5582
# Epoch 3/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7946 - loss: 0.6123 - val_accuracy: 0.8333 - val_loss: 0.5571
# Epoch 4/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7821 - loss: 0.6261 - val_accuracy: 0.8333 - val_loss: 0.5559
# Epoch 5/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8196 - loss: 0.6030 - val_accuracy: 0.8333 - val_loss: 0.5546
# Epoch 6/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7780 - loss: 0.6193 - val_accuracy: 0.8333 - val_loss: 0.5532
# Epoch 7/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8196 - loss: 0.6033 - val_accuracy: 0.8333 - val_loss: 0.5518
# Epoch 8/15
# ...

# %% [markdown]
# ### Random Small Weights

# %%
# Custom Uniform Initialization for Classification
initializer = tf.keras.initializers.RandomUniform(minval=-0.05, maxval=0.05)

def build_custom_model():
    model = Sequential([
        Dense(2, activation='relu', kernel_initializer=initializer),
        Dense(3, activation='relu', kernel_initializer=initializer),
        Dense(1, activation='sigmoid', kernel_initializer=initializer)
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

custom_model = build_custom_model()
history2 = custom_model.fit(X1_train, y1_train, epochs=15, batch_size=20, validation_data=(X1_test, y1_test))
# Out:
# Epoch 1/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6033 - loss: 0.6931 - val_accuracy: 0.6333 - val_loss: 0.6931
# Epoch 2/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5398 - loss: 0.6931 - val_accuracy: 0.4333 - val_loss: 0.6932
# Epoch 3/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5348 - loss: 0.6930 - val_accuracy: 0.4333 - val_loss: 0.6933
# Epoch 4/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4598 - loss: 0.6932 - val_accuracy: 0.4333 - val_loss: 0.6934
# Epoch 5/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4664 - loss: 0.6932 - val_accuracy: 0.4333 - val_loss: 0.6934
# Epoch 6/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5264 - loss: 0.6928 - val_accuracy: 0.4333 - val_loss: 0.6935
# Epoch 7/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5081 - loss: 0.6929 - val_accuracy: 0.4333 - val_loss: 0.6936
# Epoch 8/15
# ...

# %%
plot_history(history1, 'he_normal')
plot_history(history2, 'random')
